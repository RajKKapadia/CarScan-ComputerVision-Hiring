# %%
import matplotlib.pyplot as plt

import util

# %%
one, two = util.visualise_main(
    'Data Visualization/images/2.jpg',
    'Data Visualization/data/2.json',
    0.6
)

# %%
fig = plt.figure(figsize=(20, 15))

fig.add_subplot(1, 2, 1)
plt.imshow(one)
plt.axis('off')
plt.title('Polygones')

fig.add_subplot(1, 2, 2)
plt.imshow(two)
plt.axis('off')
plt.title('Rectangles')

plt.show()
